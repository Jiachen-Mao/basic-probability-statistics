# %% [markdown]
# # Time series analysis

# %%
import os
import sys

import pandas as pd
import pandas_datareader.data as web
import numpy as np

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from arch import arch_model

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
p = print

#p('Machine: {} {}\n'.format(os.uname().sysname, os.uname().machine))
#p(sys.version)

# %%
end = "2015-02-01"
start = "2007-01-01"
get_px = lambda x: web.DataReader(x, 'yahoo', start = start, end = end)['Adj Close']

symbols = ['SPY', 'TLT', 'MSFT']
data = pd.DataFrame({sym:get_px(sym) for sym in symbols})
lrets = np.log(data/data.shift(1)).dropna()

# %%
def tsplot(y, lags = None, figsize = (10, 8), style = 'bmh'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):
        fig = plt.figure(figsize = figsize)
        layout = (3, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan = 2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        qq_ax = plt.subplot2grid(layout, (2, 0))
        pp_ax = plt.subplot2grid(layout, (2, 1))
        
        y.plot(ax = ts_ax)
        ts_ax.set_title('Time Series Analysis Plots')
        smt.graphics.plot_acf(y, lags = lags, ax = acf_ax, alpha = 0.5)
        smt.graphics.plot_pacf(y, lags = lags, ax = pacf_ax, alpha = 0.5)
        sm.qqplot(y, line = 's', ax = qq_ax)
        qq_ax.set_title('Q-Q Plot')
        scs.probplot(y, sparams = (y.mean(), y.std()), plot = pp_ax)
        
        plt.tight_layout()
    return

# %% [markdown]
# ## Stationary
# * The mean of the series should not be a function of time.
# * The variance of the series should not be a function of time.
# * The covariance of the $i$th term and the $(i+m)$th term should not be a function of time.

# %% [markdown]
# ## Serial correlation
# #### Essentially when we model a time series we decompose the series into three components: trend, seasonal/cyclical, and random.
#
# Recall that the residuals (errors) of a stationary TS are serially uncorrelated by definition. If we fail to account for this in our model, that standard errors of our coefficients are underestimated, inflating the size of out T-statistics. The result would be too many Type-1 errors, where we reject our null hypothesis even when it is TRUE.

# %% [markdown]
# ## White Noise
# A time series that is a white noise process has serially UNcorrelated errors and the expected mean of those errors is equal to zero.

# %%
randser = np.random.normal(size = 1000)
tsplot(randser, lags = 30)

# %% [markdown]
# ## Random Walk
# A random walk is a time series model $x_t$ such that $x_t = x_{t-1} + w_t$, where $w_t$ is a discrete white noise series. It is non-stationary because the covariance between observations is time-dependent. If the TS we are modeling is a random walk, it is unpredictable

# %%
n_samples = 1000
x = w = np.random.normal(size = n_samples)

for t in range(n_samples):
    x[t] = x[t-1] + w[t]
    
_ = tsplot(x, lags = 30)

# %%
_ = tsplot(np.diff(x), lags = 30)

# %%
_ = tsplot(np.diff(data.SPY), lags = 30)

# %% [markdown]
# ## Linear Model
# Linear models are trend models representing a TS that can be graphed using a straight line.
# The basic equation is: $y_t = b_0 + b_1t + \epsilon_t$

# %%
# Example Firm ABC are -50$ by default and +25$ at every timr step

w = np.random.randn(100)
y = np.empty_like(w)

b0 = -50.
b1 = 25.
for t in range(len(w)):
    y[t] = b0 + b1*t + w[t]
    
_ = tsplot(y, lags = 30)

# %% [markdown]
# ## Log-Linear Model
#
# The data points form an exponential function that represent a constant rate ofchang with respect to each time step.

# %%
idx = pd.date_range('2007-01-01', '2012-01-01', freq = 'M')

sales = [np.exp(x/12) for x in range(1, len(idx)+1)]

df = pd.DataFrame(sales, columns = ['Sales'], index = idx)
with plt.style.context('bmh'):
    df.plot()
    plt.title("Sales")

# %%
with plt.style.context('bmh'):
    pd.Series(np.log(sales), index = idx).plot()
    plt.title('Log Sales')

# %% [markdown]
# ## Autoregressive Model - AR(p)
# When the dependent variable is regressed against one or more lagged values of itself, it is autoregressive.
# $x_t = \sum_i \alpha_i x_{t-i} + w_t$

# %%
# Simulate an AR(1) with alpha = 0.6

n_samples = int(1000)
a = 0.6
x = w = np.random.normal(size = n_samples)

for t in range(n_samples):
    x[t] = a*x[t-1] + w[t]
    
_ = tsplot(x, lags = 30)

# %%
# Fit an AR(p) model to simulated AR(1) model with alpha = 0.6

mdl = smt.AR(x).fit(maxlag = 30, ic = 'aic', trend = 'nc')
# %time est_order = smt.AR(x).select_order(maxlag = 30, ic = 'aic', trend = 'nc')

true_order = 1
p('\nalpha estimate: {:3.5f} | best lag order = {}'.format(mdl.params[0], est_order))
p('\ntrue alpha = {} | true order = {}'.format(a, true_order))
# Out:
# Wall time: 33 s
#
# alpha estimate: 0.62023 | best lag order = 4
#
# true alpha = 0.6 | true order = 1

# %%
# Simulate an AR(2) process

n = int(1000)
alphas = np.array([0.666, -0.333])
betas = np.array([0.])

ar = np.r_[1, -alphas]
ma = np.r_[1, betas]

ar2 = smt.arma_generate_sample(ar = ar, ma = ma, nsample = n)
_ = tsplot(ar2, lags = 30)

# %%
# Fit an AR(p) to simulated AR(2) process

max_lag = 10
mdl = smt.AR(ar2).fit(maxlag = max_lag, ic = 'aic', trend = 'nc')
est_order = smt.AR(ar2).select_order(maxlag = max_lag, ic = 'aic', trend = 'nc')

true_order = 2
p('\ncoeff estimate: {:3.4f} {:3.4f} | best lag order = {}'.format(mdl.params[0], mdl.params[0], est_order))
p('\ntrue coeff = {} | true order = {}'.format(alphas, true_order))
# Out:
# coeff estimate: 0.6802 0.6802 | best lag order = 4
#
# true coeff = [ 0.666 -0.333] | true order = 2

# %%
# Select best lag order for MSFT returns

max_lag = 30
mdl = smt.AR(lrets.MSFT).fit(maxlag = max_lag, ic = 'aic', trend = 'nc')
est_order = smt.AR(lrets.MSFT).select_order(maxlag = max_lag, ic = 'aic', trend = 'nc')

p('best estimated lag order = {}'.format(est_order))
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# best estimated lag order = 23

# %% [markdown]
# ## Moving Average Model - MA(q)
# MA(q) is a linear combination of past white noise error terms.
# $x_t = w_t + \sum_i w_{t-i}$

# %%
# Simulate an MA(1) process

n = int(1000)
alphas = np.array([0.])
betas = np.array([0.6])

ar = np.r_[1, -alphas]
ma = np.r_[1, betas]

ma1 = smt.arma_generate_sample(ar = ar, ma = ma, nsample = n)
_ = tsplot(ma1, lags = 30)

# %%
# Fit MA(1) model to oursimulated TS
# Specify ARMA model with order (p, q)

max_lag = 30
mdl = smt.ARMA(ma1, order = (0, 1)).fit(maxlag = max_lag, method = 'mle', trend = 'nc')
p(mdl.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                     ARMA(0, 1)   Log Likelihood               -1404.096
# Method:                           mle   S.D. of innovations              0.985
# Date:                Sat, 20 Jul 2019   AIC                           2812.193
# Time:                        12:24:46   BIC                           2822.008
# Sample:                             0   HQIC                          2815.923
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1.y        0.5851      0.025     22.973      0.000       0.535       0.635
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# ...

# %%
# Simulate an MA(3) process

n = int(1000)
alphas = np.array([0.])
betas = np.array([0.6, 0.4, 0.2])

ar = np.r_[1, -alphas]
ma = np.r_[1, betas]

ma3 = smt.arma_generate_sample(ar = ar, ma = ma, nsample = n)
_ = tsplot(ma3, lags = 30)

# %%
# Fit MA(3) model to oursimulated TS
# Specify ARMA model with order (p, q)

max_lag = 30
mdl = smt.ARMA(ma3, order = (0, 3)).fit(maxlag = max_lag, method = 'mle', trend = 'nc')
p(mdl.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                     ARMA(0, 3)   Log Likelihood               -1414.775
# Method:                           mle   S.D. of innovations              0.996
# Date:                Sat, 20 Jul 2019   AIC                           2837.550
# Time:                        12:24:48   BIC                           2857.181
# Sample:                             0   HQIC                          2845.011
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1.y        0.5867      0.030     19.328      0.000       0.527       0.646
# ma.L2.y        0.3711      0.035     10.657      0.000       0.303       0.439
# ma.L3.y        0.2151      0.032      6.745      0.000       0.153       0.278
#                                     Roots
# ...

# %%
# Fit MA(3) to SPY returns

max_lag = 30
Y = lrets.SPY
mdl = smt.ARMA(Y, order = (0, 3)).fit(maxlag = max_lag, method = 'mle', trend = 'nc')
p(mdl.summary())
_ = tsplot(mdl.resid, lags = 30)
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ...
# Dep. Variable:                    SPY   No. Observations:                 2034
# Model:                     ARMA(0, 3)   Log Likelihood                5821.428
# Method:                           mle   S.D. of innovations              0.014
# Date:                Sat, 20 Jul 2019   AIC                         -11634.856
# Time:                        12:24:49   BIC                         -11612.385
# Sample:                             0   HQIC                        -11626.612
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Autoregressive Moving Average Model - ARMA(p, q)
# ARMA model is the merger between AR(p) and MA(q) models.
# * AR(p) models try to capture the momentum and mean reversion effects often observed in trading markets.
# * MA(q) models try to capture the shock effects observed in the white noise terms. These shock effects could be thought of as unexpected events affecting the observation process, e.g., surprise earnings, terrorit attack, etc.
#
# $x_t = \sum_i \alpha_i x_{t-i} + w_t + \sum_i \beta_i w_{t-i}$
#
# #### ARMA's weakness is that it ignores the volatility clustering effects found in most financial time series.

# %%
# Simulate an ARMA(2, 2) model

n = int(5000)
burn = int(n/10) # number of samples to discard before fit
alphas = np.array([0.5, -0.25])
betas = np.array([0.5, -0.3])

ar = np.r_[1, -alphas]
ma = np.r_[1, betas]

arma22 = smt.arma_generate_sample(ar = ar, ma = ma, nsample = n, burnin = burn)
_ = tsplot(arma22, lags = 30)

# %%
mdl = smt.ARMA(arma22, order = (2, 2)).fit(maxlag = max_lag, method = 'mle', trend = 'nc', burnin = burn)
p(mdl.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 5000
# Model:                     ARMA(2, 2)   Log Likelihood               -7070.706
# Method:                           mle   S.D. of innovations              0.995
# Date:                Sat, 20 Jul 2019   AIC                          14151.413
# Time:                        12:24:56   BIC                          14183.999
# Sample:                             0   HQIC                         14162.834
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1.y        0.3825      0.063      6.084      0.000       0.259       0.506
# ar.L2.y       -0.2489      0.015    -16.302      0.000      -0.279      -0.219
# ma.L1.y        0.6273      0.065      9.717      0.000       0.501       0.754
# ...

# %%
# Fit ARMA model to SPY returns

best_aic = np.inf
best_order = None
best_mdl = None

rng = range(5)
for i in rng:
    for j in rng:
        try:
            tmp_mdl = smt.ARMA(lrets['SPY'], order = (i, j)).fit(method = 'mle', trend = 'nc')
            tmp_aic = tmp_mdl.aic
            if tmp_aic < best_aic:
                best_aic = tmp_aic
                best_order = (i, j)
                best_mdl = tmp_mdl
        except: continue

p('aic: {:6.5f} | order: {}'.format(best_aic, best_order))
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %% [markdown]
# ## Autoregressive Integrated Moving Average Model - ARIMA(p, d, q)
# ARIMA is a natural extension to the class of ARMA models. We take the nonstationary random walk and transform it into stationary white noise by differencing.

# %%
# Fit ARIMA(p, d, q) model to SPY returns

best_aic = np.inf
best_order = None
best_mdl = None

rng = range(5)
d_rng = range(2)
for i in rng:
    for d in d_rng:
        for j in rng:
            try:
                tmp_mdl = smt.ARMA(lrets['SPY'], order = (i, d, j)).fit(method = 'mle', trend = 'nc')
                tmp_aic = tmp_mdl.aic
                if tmp_aic < best_aic:
                    best_aic = tmp_aic
                    best_order = (i, d, j)
                    best_mdl = tmp_mdl
            except: continue

p('aic: {:6.5f} | order: {}'.format(best_aic, best_order))
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
_ = tsplot(best_mdl.resid, lags = 30)

# %%
# Create a 21 day forecast of SPY returns with 95%, 99% CI

n_steps = 21

f, err95, ci95 = best_mdl.forecast(steps = n_steps)
_, err99, ci99 = best_mdl.forecast(steps = n_steps, alpha = 0.01)

idx = pd.date_range(data.index[-1], periods = n_steps, freq = 'D')
fc_95 = pd.DataFrame(np.column_stack([f, ci95]), index = idx, columns = ['forecast', 'lower_ci_95', 'upper_ci_95'])
fc_99 = pd.DataFrame(np.column_stack([ci95]), index = idx, columns = ['lower_ci_99', 'upper_ci_99'])
fc_all = fc_95.combine_first(fc_99)
fc_all.head()
# Out:
#             forecast  lower_ci_95  lower_ci_99  upper_ci_95  upper_ci_99
# 2015-02-02 -0.000122    -0.027228    -0.027228     0.026984     0.026984
# 2015-02-03 -0.001040    -0.028275    -0.028275     0.026195     0.026195
# 2015-02-04  0.000112    -0.027200    -0.027200     0.027425     0.027425
# 2015-02-05  0.000078    -0.027238    -0.027238     0.027394     0.027394
# 2015-02-06 -0.000017    -0.027334    -0.027334     0.027299     0.027299

# %% [markdown]
# ## Autoregressive Conditionally Heteroskedastic Model - ARCH(p)
# ARCH(p) model can be thought of as simply as an AR(p) model applied to the variance of a time series.
# Another way to think about it, is that the variance of our time series NOW at time $t$ is conditional on past observations of the variance in previous periods.
# $Var(y_t | y_{t-1}) = \sigma_t^2 = \alpha_0 + \alpha_1 y_{t-1}^2$
#
# Assuming the series has zero mean, we can express the model as:
# $y_t = \sigma_t \epsilon_t$ with $\sigma_t = \sqrt{\alpha_0 + \alpha_1 y_{t-1}^2}$ and $\epsilon_t \sim iid(0, 1)$

# %%
# Simulate ARCH(1)

a0 = 2.
a1 = .5

y = w = np.random.normal(size = 1000)
Y = np.empty_like(y)

for t in range(len(y)):
    Y[t] = w[t] * np.sqrt((a0 + a1*y[t-1]**2))
    
tsplot(Y, lags = 30)

# %%
tsplot(Y**2, lags = 30)

# %% [markdown]
# ## Generalized Autoregressive Conditional Heteroskedastic Model - GARCH(p, q)
# GARPH(p, q) is an ARMA model applied to the variance of a time series, i.e., it has an autoregressive term and a moving average term. The AR(p) models that variance of the residuals or simply out time series squared. The MA(q) models the variance of the process. The basic form of GARCH(1, 1) is:
# $\epsilon_t = \sigma_t w_t$
# $\sigma_t^2 = \alpha_0 + \alpha_1 \epsilon_{t-1}^2 + \beta_1 \sigma_{t-1}^2$
# where $w$ is the white noise, and $\alpha$ and $\beta$ are parameters of the model. Also, $\alpha + \beta$ must be less than 1 or the model is unstable.

# %%
# Simulate a GARCH(1, 1)

a0 = .2
a1 = .5
b1 = .3

w = np.random.normal(size = 1000)
eps = np.zeros_like(w)
sigsq = np.zeros_like(w)

for i in range(1, 1000):
    sigsq[i] = a0 + a1 * (eps[i-1]**2) + b1 * sigsq[i-1]
    eps[i] = w[i] * np.sqrt(sigsq[i])
    
_ = tsplot(eps, lags = 30)

# %%
# Run through an example using SPY returns.

# 1. Iterate through combinations of ARIMA(p, d, q) models to best fit out time series.
# 2. Pick the GARCH model orders according to the ARIMA model with lowest AIC.
# 3. Fit the GARCH(p, q) model to our time series.
# 4. Examine the model residuals and squared residuals for autocorrelation.

def _get_best_model(TS):
    best_aic = np.inf
    best_order = None
    best_mdl = None
    
    pq_rng = range(5)
    d_rng = range(3)
    for i in pq_rng:
        for d in d_rng:
            for j in pq_rng:
                try:
                    tmp_mdl = smt.ARIMA(TS, order = (i, d, j)).fit(method = 'mle', trend = 'nc')
                    tmp_aic = tmp_mdl.aic
                    if tmp_aic < best_aic:
                        best_aic = tmp_aic
                        best_order = (i, d, j)
                        best_mdl = tmp_mdl
                except: continue
    p('aic: {:6.5f} | order: {}'.format(best_aic, best_order))
    return best_aic, best_order, best_mdl

# %%
TS = lrets.SPY.ix['2012':'2015']
res_tup = _get_best_model(TS)
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\maoja\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
tsplot(res_tup[2].resid, lags = 30)

# %%
tsplot(res_tup[2].resid**2, lags = 30)

# %%
# Now we fit the arch model using the best fit arima model parameters

p_ = res_tup[1][0]
o_ = res_tup[1][1]
q_ = res_tup[1][2]

am = arch_model(TS, p = p_, o = o_, q = q_, dist = 'StudentsT')
res = am.fit(update_freq = 5, disp = 'off')
p(res.summary())
# Out:
#                          Constant Mean - ARCH Model Results
# ...
# Dep. Variable:                          SPY   R-squared:                      -0.302
# Mean Model:                   Constant Mean   Adj. R-squared:                 -0.302
# Vol Model:                             ARCH   Log-Likelihood:                1818.31
# Distribution:      Standardized Student's t   AIC:                          -3628.62
# Method:                  Maximum Likelihood   BIC:                          -3610.01
#                                               No. Observations:                  775
# Date:                      Sat, Jul 20 2019   Df Residuals:                      771
# Time:                              12:26:07   Df Model:                            4
#                                    Mean Model
# ...
#                   coef    std err          t      P>|t|        95.0% Conf. Int.
# -------------------------------------------------------------------------------
# ...

# %%
tsplot(res.resid, lags = 30)
